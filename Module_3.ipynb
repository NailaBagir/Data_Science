# %%
import numpy as np
from pandas import Series, DataFrame
import pandas as pd

# %%
df=pd.read_csv("/Users/Naila/Desktop/Datasets/datasets_supermarket_sales - Sheet1 2.csv")
df.head(10)
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
# 5  699-14-3026      C  Naypyitaw        Normal    Male
# 6  355-53-5943      A     Yangon        Member  Female
# 7  315-22-5665      C  Naypyitaw        Normal  Female
# 8  665-32-9167      A     Yangon        Member  Female
# 9  692-92-5582      B   Mandalay        Member  Female
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# ...

# %%
df.iloc[:6,:3]
# Out:
#      InvoiceID Branch       City
# 0  750-67-8428      A     Yangon
# 1  226-31-3081      C  Naypyitaw
# 2  631-41-3108      A     Yangon
# 3  123-19-1176      A     Yangon
# 4  373-73-7910      A     Yangon
# 5  699-14-3026      C  Naypyitaw

# %%
df.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  976.000000
# mean     55.672130     5.510000    15.379369   322.966749  306.719252
# std      26.494628     2.923431    11.708825   245.885335  234.676918
# min      10.080000     1.000000     0.508500    10.678500   10.170000
# 25%      32.875000     3.000000     5.924875   124.422375  116.495000
# 50%      55.230000     5.000000    12.088000   253.848000  241.320000
# 75%      77.935000     8.000000    22.445250   471.350250  448.905000
# max      99.960000    10.000000    49.650000  1042.650000  993.000000
#
#        gross margin percentage  gross income      Rating
# count             9.860000e+02    990.000000  997.000000
# mean              4.761905e+00     15.350742    6.973521
# std               6.220404e-14     11.719033    1.720500
# min               4.761905e+00      0.508500    4.000000
# ...

# %%
df.columns= ['InvoiceID', 'Branch', 'City', 'CustomerType', 'Gender',
       'ProductLine', 'UnitPrice', 'Quantity', 'Tax5%', 'Total', 'Date',
       'Time', 'Payment', 'cogs', 'grossMarginPercentage', 'GrossIncome',
       'Rating']
df
# Out:
#        InvoiceID Branch       City CustomerType  Gender  \
# 0    750-67-8428      A     Yangon       Member  Female
# 1    226-31-3081      C  Naypyitaw       Normal  Female
# 2    631-41-3108      A     Yangon       Normal    Male
# 3    123-19-1176      A     Yangon       Member    Male
# 4    373-73-7910      A     Yangon       Normal    Male
# ..           ...    ...        ...          ...     ...
# 995  233-67-5758      C  Naypyitaw       Normal    Male
# 996  303-96-2227      B   Mandalay       Normal  Female
# 997  727-02-1313      A     Yangon       Member    Male
# 998  347-56-2442      A     Yangon       Normal    Male
# 999  849-09-3807      A     Yangon       Member  Female
#
#                 ProductLine  UnitPrice  Quantity    Tax5%      Total  \
# 0         Health and beauty      74.69         7  26.1415   548.9715
# 1    Electronic accessories      15.28         5   3.8200    80.2200
# 2        Home and lifestyle      46.33         7  16.2155   340.5255
# ...

# %%
df.ProductLine
# Out:
# 0           Health and beauty
# 1      Electronic accessories
# 2          Home and lifestyle
# 3           Health and beauty
# 4           Sports and travel
#                 ...
# 995         Health and beauty
# 996        Home and lifestyle
# 997        Food and beverages
# 998        Home and lifestyle
# 999       Fashion accessories
# Name: ProductLine, Length: 1000, dtype: object

# %%
df.tail(10)
# Out:
#        InvoiceID Branch       City CustomerType  Gender  \
# 990  886-18-2897      A     Yangon       Normal  Female
# 991  602-16-6955      B   Mandalay       Normal  Female
# 992  745-74-0715      A     Yangon       Normal    Male
# 993  690-01-6631      B   Mandalay       Normal    Male
# 994  652-49-6720      C  Naypyitaw       Member  Female
# 995  233-67-5758      C  Naypyitaw       Normal    Male
# 996  303-96-2227      B   Mandalay       Normal  Female
# 997  727-02-1313      A     Yangon       Member    Male
# 998  347-56-2442      A     Yangon       Normal    Male
# 999  849-09-3807      A     Yangon       Member  Female
#
#                 ProductLine  UnitPrice  Quantity    Tax5%      Total  \
# 990      Food and beverages      56.56         5  14.1400   296.9400
# 991       Sports and travel      76.60        10  38.3000   804.3000
# 992  Electronic accessories      58.03         2   5.8030   121.8630
# ...

# %%
df[["CustomerType","ProductLine","cogs"]][90:110]
# Out:
#     CustomerType             ProductLine    cogs
# 90        Member      Home and lifestyle  189.52
# 91        Normal       Sports and travel  448.60
# 92        Member       Sports and travel  153.86
# 93        Member       Health and beauty  579.24
# 94        Normal       Health and beauty   89.75
# 95        Normal  Electronic accessories   97.16
# 96        Normal       Health and beauty  878.70
# 97        Normal  Electronic accessories   74.70
# 98        Normal      Food and beverages  158.25
# 99        Normal      Home and lifestyle  496.20
# 100       Member     Fashion accessories   48.71
# 101       Normal     Fashion accessories  706.95
# 102       Normal  Electronic accessories  207.63
# 103       Normal      Food and beverages  349.56
# 104       Normal       Health and beauty  212.45
# 105       Member  Electronic accessories  886.70
# 106       Normal     Fashion accessories  164.28
# 107       Normal       Sports and travel  372.78
# ...

# %%
df[df["Payment"].isnull()]
# Out:
#      InvoiceID Branch    City CustomerType  Gender        ProductLine  \
# 0  750-67-8428      A  Yangon       Member  Female  Health and beauty
# 3  123-19-1176      A  Yangon       Member    Male  Health and beauty
#
#    UnitPrice  Quantity    Tax5%     Total       Date   Time Payment    cogs  \
# 0      74.69         7  26.1415  548.9715   1/5/2019  13:08     NaN  522.83
# 3      58.22         8  23.2880  489.0480  1/27/2019  20:33     NaN     NaN
#
#    grossMarginPercentage  GrossIncome  Rating
# 0               4.761905      26.1415     9.1
# 3               4.761905          NaN     8.4

# %%
import warnings
warnings.filterwarnings("ignore")
df.Payment[df.Payment.isnull()]="Ewallet"
df.head()
# Out:
#      InvoiceID Branch       City CustomerType  Gender             ProductLine  \
# 0  750-67-8428      A     Yangon       Member  Female       Health and beauty
# 1  226-31-3081      C  Naypyitaw       Normal  Female  Electronic accessories
# 2  631-41-3108      A     Yangon       Normal    Male      Home and lifestyle
# 3  123-19-1176      A     Yangon       Member    Male       Health and beauty
# 4  373-73-7910      A     Yangon       Normal    Male       Sports and travel
#
#    UnitPrice  Quantity    Tax5%     Total       Date   Time      Payment  \
# 0      74.69         7  26.1415  548.9715   1/5/2019  13:08      Ewallet
# 1      15.28         5   3.8200   80.2200   3/8/2019  10:29         Cash
# 2      46.33         7  16.2155  340.5255   3/3/2019  13:23  Credit card
# 3      58.22         8  23.2880  489.0480  1/27/2019  20:33      Ewallet
# 4      86.31         7  30.2085  634.3785   2/8/2019  10:37      Ewallet
#
#      cogs  grossMarginPercentage  GrossIncome  Rating
# ...

# %%
df.head().unstack()
# Out:
# InvoiceID  0    750-67-8428
#            1    226-31-3081
#            2    631-41-3108
#            3    123-19-1176
#            4    373-73-7910
#                    ...
# Rating     0            9.1
#            1            9.6
#            2            7.4
#            3            8.4
#            4            5.3
# Length: 85, dtype: object

# %%
df.head().stack()
# Out:
# 0  InvoiceID       750-67-8428
#    Branch                    A
#    City                 Yangon
#    CustomerType         Member
#    Gender               Female
#                       ...
# 4  Time                  10:37
#    Payment             Ewallet
#    cogs                 604.17
#    GrossIncome         30.2085
#    Rating                  5.3
# Length: 80, dtype: object

# %%
df.head().unstack().unstack()
# Out:
#                                        0                       1  \
# InvoiceID                    750-67-8428             226-31-3081
# Branch                                 A                       C
# City                              Yangon               Naypyitaw
# CustomerType                      Member                  Normal
# Gender                            Female                  Female
# ProductLine            Health and beauty  Electronic accessories
# UnitPrice                          74.69                   15.28
# Quantity                               7                       5
# Tax5%                            26.1415                    3.82
# Total                            548.971                   80.22
# Date                            1/5/2019                3/8/2019
# Time                               13:08                   10:29
# Payment                          Ewallet                    Cash
# ...

# %%
df[0:40].dropna()
# Out:
#       InvoiceID Branch       City CustomerType  Gender  \
# 0   750-67-8428      A     Yangon       Member  Female
# 13  252-56-2699      A     Yangon       Normal    Male
# 25  227-03-5010      A     Yangon       Member  Female
# 26  649-29-6775      B   Mandalay       Normal    Male
# 28  145-94-9061      B   Mandalay       Normal  Female
# 30  871-79-8483      B   Mandalay       Normal    Male
# 31  149-71-6266      B   Mandalay       Member    Male
# 33  595-11-5460      A     Yangon       Normal    Male
# 35  232-16-2483      C  Naypyitaw       Member  Female
# 37  272-65-1806      A     Yangon       Normal  Female
# 38  333-73-7901      C  Naypyitaw       Normal  Female
#
#                ProductLine  UnitPrice  Quantity    Tax5%     Total       Date  \
# 0        Health and beauty      74.69         7  26.1415  548.9715   1/5/2019
# 13      Food and beverages      43.19        10  21.5950  453.4950   2/7/2019
# ...

# %%
df[20:30][::-1].fillna(method='ffill',limit=3)
# Out:
#       InvoiceID Branch       City CustomerType  Gender  \
# 29  848-62-7243      A     Yangon       Normal    Male
# 28  145-94-9061      B   Mandalay       Normal  Female
# 27  189-17-4241      A     Yangon       Normal  Female
# 26  649-29-6775      B   Mandalay       Normal    Male
# 25  227-03-5010      A     Yangon       Member  Female
# 24  549-59-1358      A     Yangon       Member    Male
# 23  636-48-8204      A     Yangon       Normal    Male
# 22  273-16-6619      B   Mandalay       Normal    Male
# 21  371-85-5789      B   Mandalay       Normal    Male
# 20  300-71-4605      C  Naypyitaw       Member    Male
#
#                ProductLine  UnitPrice  Quantity    Tax5%     Total       Date  \
# 29       Health and beauty      24.89         9  11.2005  235.2105  3/15/2019
# 28      Food and beverages      88.36         5  22.0900  463.8900  1/25/2019
# 27     Fashion accessories      87.67         2   8.7670  184.1070  3/10/2019
# ...

# %%
df[0:20].fillna({'cogs':5,'gross margin percentage':10,'gross income':15})
# Out:
#       InvoiceID Branch       City CustomerType  Gender  \
# 0   750-67-8428      A     Yangon       Member  Female
# 1   226-31-3081      C  Naypyitaw       Normal  Female
# 2   631-41-3108      A     Yangon       Normal    Male
# 3   123-19-1176      A     Yangon       Member    Male
# 4   373-73-7910      A     Yangon       Normal    Male
# 5   699-14-3026      C  Naypyitaw       Normal    Male
# 6   355-53-5943      A     Yangon       Member  Female
# 7   315-22-5665      C  Naypyitaw       Normal  Female
# 8   665-32-9167      A     Yangon       Member  Female
# 9   692-92-5582      B   Mandalay       Member  Female
# 10  351-62-0822      B   Mandalay       Member  Female
# 11  529-56-3974      B   Mandalay       Member    Male
# 12  365-64-0515      A     Yangon       Normal  Female
# 13  252-56-2699      A     Yangon       Normal    Male
# 14  829-34-3910      A     Yangon       Normal  Female
# 15  299-46-1805      B   Mandalay       Member  Female
# ...

# %%
df[10:15][::-1].fillna(method='ffill')
# Out:
#       InvoiceID Branch      City CustomerType  Gender             ProductLine  \
# 14  829-34-3910      A    Yangon       Normal  Female       Health and beauty
# 13  252-56-2699      A    Yangon       Normal    Male      Food and beverages
# 12  365-64-0515      A    Yangon       Normal  Female  Electronic accessories
# 11  529-56-3974      B  Mandalay       Member    Male  Electronic accessories
# 10  351-62-0822      B  Mandalay       Member  Female     Fashion accessories
#
#     UnitPrice  Quantity    Tax5%     Total       Date   Time  Payment    cogs  \
# 14      71.38        10  35.6900  749.4900  3/29/2019  19:21     Cash  713.80
# 13      43.19        10  21.5950  453.4950   2/7/2019  16:48  Ewallet  431.90
# 12      46.95         5  11.7375  246.4875  2/12/2019  10:25  Ewallet  431.90
# 11      25.51         4   5.1020  107.1420   3/9/2019  17:03     Cash  102.04
# 10      14.48         4   2.8960   60.8160   2/6/2019  18:07  Ewallet  102.04
#
# ...

# %%
df[10:15].fillna(method='bfill')
# Out:
#       InvoiceID Branch      City CustomerType  Gender             ProductLine  \
# 10  351-62-0822      B  Mandalay       Member  Female     Fashion accessories
# 11  529-56-3974      B  Mandalay       Member    Male  Electronic accessories
# 12  365-64-0515      A    Yangon       Normal  Female  Electronic accessories
# 13  252-56-2699      A    Yangon       Normal    Male      Food and beverages
# 14  829-34-3910      A    Yangon       Normal  Female       Health and beauty
#
#     UnitPrice  Quantity    Tax5%     Total       Date   Time  Payment    cogs  \
# 10      14.48         4   2.8960   60.8160   2/6/2019  18:07  Ewallet  102.04
# 11      25.51         4   5.1020  107.1420   3/9/2019  17:03     Cash  102.04
# 12      46.95         5  11.7375  246.4875  2/12/2019  10:25  Ewallet  431.90
# 13      43.19        10  21.5950  453.4950   2/7/2019  16:48  Ewallet  431.90
# 14      71.38        10  35.6900  749.4900  3/29/2019  19:21     Cash  713.80
#
# ...

# %%
df[15:20].fillna(df.mean())
# Out:
#       InvoiceID Branch      City CustomerType  Gender         ProductLine  \
# 15  299-46-1805      B  Mandalay       Member  Female   Sports and travel
# 16  656-95-9349      A    Yangon       Member  Female   Health and beauty
# 17  765-26-6951      A    Yangon       Normal    Male   Sports and travel
# 18  329-62-1586      A    Yangon       Normal    Male  Food and beverages
# 19  319-50-3348      B  Mandalay       Normal  Female  Home and lifestyle
#
#     UnitPrice  Quantity    Tax5%     Total       Date   Time      Payment  \
# 15      93.72         6  28.1160  590.4360  1/15/2019  16:19         Cash
# 16      68.93         7  24.1255  506.6355  3/11/2019  11:03  Credit card
# 17      72.61         6  21.7830  457.4430   1/1/2019  10:39  Credit card
# 18      54.67         3   8.2005  172.2105  1/21/2019  18:00  Credit card
# 19      40.30         2   4.0300   84.6300  3/11/2019  15:30      Ewallet
#
#           cogs  grossMarginPercentage  GrossIncome    Rating
# ...

# %%
count=df.Payment.value_counts()
print(count)
df[0:5].fillna({'Payment':count.index[0]})
# Out:
# Cash           344
# Ewallet        343
# Credit card    311
# Name: Payment, dtype: int64
#      InvoiceID Branch       City CustomerType  Gender             ProductLine  \
# 0  750-67-8428      A     Yangon       Member  Female       Health and beauty
# 1  226-31-3081      C  Naypyitaw       Normal  Female  Electronic accessories
# 2  631-41-3108      A     Yangon       Normal    Male      Home and lifestyle
# 3  123-19-1176      A     Yangon       Member    Male       Health and beauty
# 4  373-73-7910      A     Yangon       Normal    Male       Sports and travel
#
#    UnitPrice  Quantity    Tax5%     Total       Date   Time      Payment  \
# 0      74.69         7  26.1415  548.9715   1/5/2019  13:08         Cash
# 1      15.28         5   3.8200   80.2200   3/8/2019  10:29         Cash
# 2      46.33         7  16.2155  340.5255   3/3/2019  13:23  Credit card
# 3      58.22         8  23.2880  489.0480  1/27/2019  20:33         Cash
# ...

# %%
TPrice=df.UnitPrice*df.Quantity
df["TPrice"]=TPrice
df.head()
# Out:
#      InvoiceID Branch       City CustomerType  Gender             ProductLine  \
# 0  750-67-8428      A     Yangon       Member  Female       Health and beauty
# 1  226-31-3081      C  Naypyitaw       Normal  Female  Electronic accessories
# 2  631-41-3108      A     Yangon       Normal    Male      Home and lifestyle
# 3  123-19-1176      A     Yangon       Member    Male       Health and beauty
# 4  373-73-7910      A     Yangon       Normal    Male       Sports and travel
#
#    UnitPrice  Quantity    Tax5%     Total       Date   Time      Payment  \
# 0      74.69         7  26.1415  548.9715   1/5/2019  13:08          NaN
# 1      15.28         5   3.8200   80.2200   3/8/2019  10:29         Cash
# 2      46.33         7  16.2155  340.5255   3/3/2019  13:23  Credit card
# 3      58.22         8  23.2880  489.0480  1/27/2019  20:33          NaN
# 4      86.31         7  30.2085  634.3785   2/8/2019  10:37      Ewallet
#
# ...

# %%
df.fillna({'cogs':TPrice})
# Out:
#        InvoiceID Branch       City CustomerType  Gender  \
# 0    750-67-8428      A     Yangon       Member  Female
# 1    226-31-3081      C  Naypyitaw       Normal  Female
# 2    631-41-3108      A     Yangon       Normal    Male
# 3    123-19-1176      A     Yangon       Member    Male
# 4    373-73-7910      A     Yangon       Normal    Male
# ..           ...    ...        ...          ...     ...
# 995  233-67-5758      C  Naypyitaw       Normal    Male
# 996  303-96-2227      B   Mandalay       Normal  Female
# 997  727-02-1313      A     Yangon       Member    Male
# 998  347-56-2442      A     Yangon       Normal    Male
# 999  849-09-3807      A     Yangon       Member  Female
#
#                 ProductLine  UnitPrice  Quantity    Tax5%      Total  \
# 0         Health and beauty      74.69         7  26.1415   548.9715
# 1    Electronic accessories      15.28         5   3.8200    80.2200
# 2        Home and lifestyle      46.33         7  16.2155   340.5255
# ...

# %%
df = df.drop("TPrice",1)

# %%
df.drop([999,998,997],0).tail(5)
# Out:
#        InvoiceID Branch       City CustomerType  Gender  \
# 992  745-74-0715      A     Yangon       Normal    Male
# 993  690-01-6631      B   Mandalay       Normal    Male
# 994  652-49-6720      C  Naypyitaw       Member  Female
# 995  233-67-5758      C  Naypyitaw       Normal    Male
# 996  303-96-2227      B   Mandalay       Normal  Female
#
#                 ProductLine  UnitPrice  Quantity    Tax5%      Total  \
# 992  Electronic accessories      58.03         2   5.8030   121.8630
# 993     Fashion accessories      17.49        10   8.7450   183.6450
# 994  Electronic accessories      60.95         1   3.0475    63.9975
# 995       Health and beauty      40.35         1   2.0175    42.3675
# 996      Home and lifestyle      97.38        10  48.6900  1022.4900
#
#           Date   Time  Payment    cogs  grossMarginPercentage  GrossIncome  \
# 992  3/10/2019  20:46  Ewallet  116.06               4.761905       5.8030
# ...

# %%
df[df.cogs.isnull()].transpose().columns
# Out:
# Int64Index([ 2,  3,  5,  7, 10, 12, 17, 18, 20, 21, 22, 23, 24, 27, 32, 34, 39,
#             41, 56, 59, 68, 76, 80, 83],
#            dtype='int64')

# %%
df[(df.Total>50) & (df.Total<100)]
# Out:
#        InvoiceID Branch       City CustomerType  Gender  \
# 1    226-31-3081      C  Naypyitaw       Normal  Female
# 8    665-32-9167      A     Yangon       Member  Female
# 10   351-62-0822      B   Mandalay       Member  Female
# 19   319-50-3348      B   Mandalay       Normal  Female
# 22   273-16-6619      B   Mandalay       Normal    Male
# ..           ...    ...        ...          ...     ...
# 964  794-42-3736      B   Mandalay       Normal    Male
# 965  172-42-8274      B   Mandalay       Normal  Female
# 979  151-33-7434      B   Mandalay       Normal  Female
# 994  652-49-6720      C  Naypyitaw       Member  Female
# 998  347-56-2442      A     Yangon       Normal    Male
#
#                 ProductLine  UnitPrice  Quantity   Tax5%    Total       Date  \
# 1    Electronic accessories      15.28         5  3.8200  80.2200   3/8/2019
# 8         Health and beauty      36.26         2  3.6260  76.1460  1/10/2019
# ...

# %%
df[(df.City=="Yangon")&(df.CustomerType=="Member")&(df.ProductLine=="Electronic accessories")]
# Out:
#        InvoiceID Branch    City CustomerType  Gender             ProductLine  \
# 6    355-53-5943      A  Yangon       Member  Female  Electronic accessories
# 105  704-48-3927      A  Yangon       Member    Male  Electronic accessories
# 217  319-74-2561      A  Yangon       Member  Female  Electronic accessories
# 248  799-71-1548      A  Yangon       Member    Male  Electronic accessories
# 256  366-93-0948      A  Yangon       Member    Male  Electronic accessories
# 258  151-16-1484      A  Yangon       Member    Male  Electronic accessories
# 292  278-97-7759      A  Yangon       Member  Female  Electronic accessories
# 305  411-77-0180      A  Yangon       Member    Male  Electronic accessories
# 308  512-98-1403      A  Yangon       Member  Female  Electronic accessories
# 329  340-66-0321      A  Yangon       Member    Male  Electronic accessories
# 335  527-09-6272      A  Yangon       Member  Female  Electronic accessories
# ...

# %%
df.ProductLine.unique()
# Out:
# array(['Health and beauty', 'Electronic accessories',
#        'Home and lifestyle', 'Sports and travel', 'Food and beverages',
#        'Fashion accessories'], dtype=object)

# %%
df[::100]
# Out:
#        InvoiceID Branch       City CustomerType  Gender  \
# 0    750-67-8428      A     Yangon       Member  Female
# 100  163-56-7055      C  Naypyitaw       Member    Male
# 200  606-80-4905      C  Naypyitaw       Member  Female
# 300  446-47-6729      C  Naypyitaw       Normal    Male
# 400  110-05-6330      C  Naypyitaw       Normal  Female
# 500  277-63-2961      B   Mandalay       Member    Male
# 600  219-61-4139      C  Naypyitaw       Normal    Male
# 700  626-43-7888      C  Naypyitaw       Normal  Female
# 800  751-15-6198      B   Mandalay       Normal    Male
# 900  377-79-7592      C  Naypyitaw       Member  Female
#
#                 ProductLine  UnitPrice  Quantity    Tax5%     Total  \
# 0         Health and beauty      74.69         7  26.1415  548.9715
# 100     Fashion accessories      48.71         1   2.4355   51.1455
# 200       Sports and travel      19.15         6   5.7450  120.6450
# 300     Fashion accessories      99.82         2   9.9820  209.6220
# ...

# %%
df[::100].at[500,"City"]
# Out:
# 'Mandalay'

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")
plt.rcParams["figure.figsize"] = 12 , 4
plt1 = sns.distplot(df["Rating"], bins=10, color = "red" )

# %%
plt1 = sns.distplot(df["GrossIncome"], bins=10, color = "red" )

# %%
plt2 = sns.boxplot(data = df,x = "Payment", y = "cogs")

# %%
plt3 = sns.lmplot(data = df, x = "Tax5%", y = "Total",fit_reg = True )

# %%
plt3 = sns.lmplot(data = df, x = "Rating", y = "GrossIncome",fit_reg = True )

# %%
plt3 = sns.lmplot(data = df, x = "Rating", y = "GrossIncome",\
                   fit_reg = False ,hue="Branch",size =10,scatter_kws={"s":100})
