# %%
import pandas as pd

# %%
#Reads data
df=pd.read_csv("/Users/Naila/Desktop/Datasets/datasets_supermarket_sales - Sheet1 2.csv")

# %%
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
#length of dataframe
len(df)
# Out:
# 1000

# %%
df.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
df.columns= ['InvoiceID', 'Branch', 'City', 'CustomerType', 'Gender',
       'ProductLine', 'UnitPrice', 'Quantity', 'Tax5%', 'Total', 'Date',
       'Time', 'Payment', 'cogs', 'grossMarginPercentage', 'GrossIncome',
       'Rating']
df.head()
# Out:
#      InvoiceID Branch       City CustomerType  Gender             ProductLine  \
# 0  750-67-8428      A     Yangon       Member  Female       Health and beauty
# 1  226-31-3081      C  Naypyitaw       Normal  Female  Electronic accessories
# 2  631-41-3108      A     Yangon       Normal    Male      Home and lifestyle
# 3  123-19-1176      A     Yangon       Member    Male       Health and beauty
# 4  373-73-7910      A     Yangon       Normal    Male       Sports and travel
#
#    UnitPrice  Quantity    Tax5%     Total       Date   Time      Payment  \
# 0      74.69         7  26.1415  548.9715   1/5/2019  13:08          NaN
# 1      15.28         5   3.8200   80.2200   3/8/2019  10:29         Cash
# 2      46.33         7  16.2155  340.5255   3/3/2019  13:23  Credit card
# 3      58.22         8  23.2880  489.0480  1/27/2019  20:33          NaN
# 4      86.31         7  30.2085  634.3785   2/8/2019  10:37      Ewallet
#
#      cogs  grossMarginPercentage  GrossIncome  Rating
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   InvoiceID              200 non-null    category
#  1   Branch                 200 non-null    object
#  2   City                   200 non-null    object
#  3   CustomerType           200 non-null    object
#  4   Gender                 200 non-null    category
#  5   ProductLine            200 non-null    category
#  6   UnitPrice              200 non-null    float64
#  7   Quantity               200 non-null    int64
#  8   Tax5%                  200 non-null    float64
#  9   Total                  200 non-null    float64
#  10  Date                   200 non-null    object
#  11  Time                   200 non-null    object
#  12  Payment                199 non-null    category
#  13  cogs                   200 non-null    float64
# ...

# %%
df.describe()
# Out:
#          UnitPrice     Quantity        Tax5%        Total        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  976.000000
# mean     55.672130     5.510000    15.379369   322.966749  306.719252
# std      26.494628     2.923431    11.708825   245.885335  234.676918
# min      10.080000     1.000000     0.508500    10.678500   10.170000
# 25%      32.875000     3.000000     5.924875   124.422375  116.495000
# 50%      55.230000     5.000000    12.088000   253.848000  241.320000
# 75%      77.935000     8.000000    22.445250   471.350250  448.905000
# max      99.960000    10.000000    49.650000  1042.650000  993.000000
#
#        grossMarginPercentage  GrossIncome      Rating
# count           9.860000e+02   990.000000  997.000000
# mean            4.761905e+00    15.350742    6.973521
# std             6.220404e-14    11.719033    1.720500
# min             4.761905e+00     0.508500    4.000000
# 25%             4.761905e+00     5.960500    5.500000
# ...

# %%
#sets Payment's type category
df.Payment.astype('category')
# Out:
# 0              NaN
# 1             Cash
# 2      Credit card
# 3              NaN
# 4          Ewallet
#           ...
# 995        Ewallet
# 996        Ewallet
# 997           Cash
# 998           Cash
# 999           Cash
# Name: Payment, Length: 1000, dtype: category
# Categories (3, object): [Cash, Credit card, Ewallet]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   InvoiceID              1000 non-null   object
#  1   Branch                 1000 non-null   object
#  2   City                   1000 non-null   object
#  3   CustomerType           1000 non-null   object
#  4   Gender                 1000 non-null   object
#  5   ProductLine            1000 non-null   object
#  6   UnitPrice              1000 non-null   float64
#  7   Quantity               1000 non-null   int64
#  8   Tax5%                  1000 non-null   float64
#  9   Total                  1000 non-null   float64
#  10  Date                   1000 non-null   object
#  11  Time                   1000 non-null   object
#  12  Payment                998 non-null    object
#  13  cogs                   976 non-null    float64
# ...

# %%
df.Payment=df.Payment.astype('category')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   InvoiceID              1000 non-null   object
#  1   Branch                 1000 non-null   object
#  2   City                   1000 non-null   object
#  3   CustomerType           1000 non-null   object
#  4   Gender                 1000 non-null   object
#  5   ProductLine            1000 non-null   object
#  6   UnitPrice              1000 non-null   float64
#  7   Quantity               1000 non-null   int64
#  8   Tax5%                  1000 non-null   float64
#  9   Total                  1000 non-null   float64
#  10  Date                   1000 non-null   object
#  11  Time                   1000 non-null   object
#  12  Payment                998 non-null    category
#  13  cogs                   976 non-null    float64
# ...

# %%
df.Gender=df.Gender.astype('category')
df.InvoiceID=df.InvoiceID.astype('category')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   InvoiceID              1000 non-null   category
#  1   Branch                 1000 non-null   object
#  2   City                   1000 non-null   object
#  3   CustomerType           1000 non-null   object
#  4   Gender                 1000 non-null   category
#  5   ProductLine            1000 non-null   object
#  6   UnitPrice              1000 non-null   float64
#  7   Quantity               1000 non-null   int64
#  8   Tax5%                  1000 non-null   float64
#  9   Total                  1000 non-null   float64
#  10  Date                   1000 non-null   object
#  11  Time                   1000 non-null   object
#  12  Payment                998 non-null    category
#  13  cogs                   976 non-null    float64
# ...

# %%
df.Payment.unique()
# Out:
# [NaN, Cash, Credit card, Ewallet]
# Categories (3, object): [Cash, Credit card, Ewallet]

# %%
df.Payment.cat.categories
# Out:
# Index(['Cash', 'Credit card', 'Ewallet'], dtype='object')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore") 
plt.rcParams["figure.figsize"] = 8 , 4

# %%
df.head()
# Out:
#      InvoiceID Branch       City CustomerType  Gender             ProductLine  \
# 0  750-67-8428      A     Yangon       Member  Female       Health and beauty
# 1  226-31-3081      C  Naypyitaw       Normal  Female  Electronic accessories
# 2  631-41-3108      A     Yangon       Normal    Male      Home and lifestyle
# 3  123-19-1176      A     Yangon       Member    Male       Health and beauty
# 4  373-73-7910      A     Yangon       Normal    Male       Sports and travel
#
#    UnitPrice  Quantity    Tax5%     Total       Date   Time      Payment  \
# 0      74.69         7  26.1415  548.9715   1/5/2019  13:08          NaN
# 1      15.28         5   3.8200   80.2200   3/8/2019  10:29         Cash
# 2      46.33         7  16.2155  340.5255   3/3/2019  13:23  Credit card
# 3      58.22         8  23.2880  489.0480  1/27/2019  20:33          NaN
# 4      86.31         7  30.2085  634.3785   2/8/2019  10:37      Ewallet
#
#      cogs  grossMarginPercentage  GrossIncome  Rating
# ...

# %%
sns.set_style('darkgrid') #changes background 
j = sns.jointplot(data = df, x = 'Quantity',y="GrossIncome", edgecolor ="black")

# %%
j = sns.jointplot(data = df, x = 'Quantity',y="GrossIncome",kind = 'hex')

# %%
ml=sns.distplot(df.Total)

# %%
mnl=plt.hist(df.Total,bins=20)

# %%
sns.set_style('darkgrid')
mnl = plt.hist(df.Rating, bins = 100)

# %%
plt.hist(df.cogs)
# Out:
# (array([230., 210., 142., 107.,  87.,  66.,  44.,  49.,  25.,  16.]),
#  array([ 10.17 , 108.453, 206.736, 305.019, 403.302, 501.585, 599.868,
#         698.151, 796.434, 894.717, 993.   ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(df.cogs)
plt.show()

# %%
df
# Out:
#        InvoiceID Branch       City CustomerType  Gender  \
# 0    750-67-8428      A     Yangon       Member  Female
# 1    226-31-3081      C  Naypyitaw       Normal  Female
# 2    631-41-3108      A     Yangon       Normal    Male
# 3    123-19-1176      A     Yangon       Member    Male
# 4    373-73-7910      A     Yangon       Normal    Male
# ..           ...    ...        ...          ...     ...
# 995  233-67-5758      C  Naypyitaw       Normal    Male
# 996  303-96-2227      B   Mandalay       Normal  Female
# 997  727-02-1313      A     Yangon       Member    Male
# 998  347-56-2442      A     Yangon       Normal    Male
# 999  849-09-3807      A     Yangon       Member  Female
#
#                 ProductLine  UnitPrice  Quantity    Tax5%      Total  \
# 0         Health and beauty      74.69         7  26.1415   548.9715
# 1    Electronic accessories      15.28         5   3.8200    80.2200
# 2        Home and lifestyle      46.33         7  16.2155   340.5255
# ...

# %%
df[df.City == 'Mandalay']
# Out:
#        InvoiceID Branch      City CustomerType  Gender  \
# 9    692-92-5582      B  Mandalay       Member  Female
# 10   351-62-0822      B  Mandalay       Member  Female
# 11   529-56-3974      B  Mandalay       Member    Male
# 15   299-46-1805      B  Mandalay       Member  Female
# 19   319-50-3348      B  Mandalay       Normal  Female
# ..           ...    ...       ...          ...     ...
# 987  552-44-5977      B  Mandalay       Member    Male
# 989  430-53-4718      B  Mandalay       Member    Male
# 991  602-16-6955      B  Mandalay       Normal  Female
# 993  690-01-6631      B  Mandalay       Normal    Male
# 996  303-96-2227      B  Mandalay       Normal  Female
#
#                 ProductLine  UnitPrice  Quantity   Tax5%     Total       Date  \
# 9        Food and beverages      54.84         3   8.226   172.746  2/20/2019
# 10      Fashion accessories      14.48         4   2.896    60.816   2/6/2019
# ...

# %%
df[df.City == 'Mandalay'].Total
# Out:
# 9       172.746
# 10       60.816
# 11      107.142
# 15      590.436
# 19       84.630
#          ...
# 987     520.800
# 989     633.108
# 991     804.300
# 993     183.645
# 996    1022.490
# Name: Total, Length: 332, dtype: float64

# %%
df.City.unique()
# Out:
# array(['Yangon', 'Naypyitaw', 'Mandalay'], dtype=object)

# %%
df.ProductLine.unique()
# Out:
# array(['Health and beauty', 'Electronic accessories',
#        'Home and lifestyle', 'Sports and travel', 'Food and beverages',
#        'Fashion accessories'], dtype=object)

# %%
df.ProductLine=df.ProductLine.astype('category')
df.ProductLine.cat.categories
# Out:
# Index(['Electronic accessories', 'Fashion accessories', 'Food and beverages',
#        'Health and beauty', 'Home and lifestyle', 'Sports and travel'],
#       dtype='object')

# %%
plt.hist(df[df.City == 'Mandalay'].Total)
# Out:
# (array([82., 72., 42., 41., 23., 24., 15., 18., 10.,  5.]),
#  array([  18.6375 ,  119.02275,  219.408  ,  319.79325,  420.1785 ,
#          520.56375,  620.949  ,  721.33425,  821.7195 ,  922.10475,
#         1022.49   ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(df[df.City == 'Yangon'].Total)
# Out:
# (array([78., 79., 52., 34., 35., 19., 17., 16.,  8.,  2.]),
#  array([  12.6945 ,  115.35405,  218.0136 ,  320.67315,  423.3327 ,
#          525.99225,  628.6518 ,  731.31135,  833.9709 ,  936.63045,
#         1039.29   ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(df[df.City == 'Naypyitaw'].Total)
# Out:
# (array([78., 63., 48., 33., 32., 25., 13., 15., 11., 10.]),
#  array([  10.6785 ,  113.87565,  217.0728 ,  320.26995,  423.4671 ,
#          526.66425,  629.8614 ,  733.05855,  836.2557 ,  939.45285,
#         1042.65   ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(df[df.City == 'Yangon'].Total)
plt.hist(df[df.City == 'Mandalay'].Total)
plt.hist(df[df.City == 'Naypyitaw'].Total)
plt.show()

# %%
plt.hist([df[df.City == 'Yangon'].Total,
        df[df.City == 'Mandalay'].Total,
        df[df.City == 'Naypyitaw'].Total])
plt.show()

# %%
plt.hist([df[df.City == 'Yangon'].Total,
        df[df.City == 'Mandalay'].Total,
        df[df.City == 'Naypyitaw'].Total],bins =15, stacked = True)
plt.show()

# %%
df.ProductLine.cat.categories
# Out:
# Index(['Electronic accessories', 'Fashion accessories', 'Food and beverages',
#        'Health and beauty', 'Home and lifestyle', 'Sports and travel'],
#       dtype='object')

# %%
for pl in df.ProductLine.cat.categories:
    print(pl)
# Out:
# Electronic accessories
# Fashion accessories
# Food and beverages
# Health and beauty
# Home and lifestyle
# Sports and travel

# %%
list1 = list()
for pl in df.ProductLine.cat.categories:
    list1.append(df[df.ProductLine == pl].cogs)
print(list1)
# Out:
# [1       76.40
# 5         NaN
# 6      413.04
# 11     102.04
# 12        NaN
#         ...
# 978     25.45
# 984    674.59
# 988    823.40
# 992    116.06
# 994     60.95
# Name: cogs, Length: 170, dtype: float64, 10        NaN
# 26      33.52
# 27        NaN
# 30     470.65
# 49     826.30
#         ...
# 974    172.26
# 975     99.84
# 985    318.55
# 993    174.90
# 999    618.38
# Name: cogs, Length: 178, dtype: float64, 9      164.52
# 13     431.90
# 18        NaN
# 28     441.80
# 34        NaN
#         ...
# 977    159.60
# 979     67.77
# 980    238.36
# 990    282.80
# 997     31.84
# Name: cogs, Length: 174, dtype: float64, 0      522.83
# 3         NaN
# 8       72.52
# 14     713.80
# 16     482.51
#         ...
# 983    699.72
# 986     29.52
# 987    496.00
# 989    602.96
# 995     40.35
# Name: cogs, Length: 152, dtype: float64, 2         NaN
# 7         NaN
# 19      80.60
# 22        NaN
# 25     420.72
#         ...
# 967    243.03
# 971    258.37
# ...

# %%
h= plt.hist(list1,bins =30)

# %%
h= plt.hist(list1,bins =30, stacked =True)

# %%
import  numpy as np
df[df.ProductLine == "Electronic accessories"].cogs.mean()
# Out:
# 303.82357575757567

# %%
df[df.ProductLine == "Fashion accessories"].cogs.mean()
# Out:
# 291.68731428571414

# %%
list1 = list()
mylabels = list()
for pl in df.ProductLine.cat.categories:
    list1.append(df[df.ProductLine == pl].cogs)
    mylabels.append(pl)
plt.hist(list1,bins =30, stacked =True, label = mylabels)
plt.legend()
plt.show()

# %%
# Kde Plot
visl = sns.lmplot(data = df, x ="Rating", y = "GrossIncome", \
                  fit_reg =False, hue ='ProductLine',  size =6, aspect=1)

# %%
df.head()
# Out:
#      InvoiceID Branch       City CustomerType  Gender             ProductLine  \
# 0  750-67-8428      A     Yangon       Member  Female       Health and beauty
# 1  226-31-3081      C  Naypyitaw       Normal  Female  Electronic accessories
# 2  631-41-3108      A     Yangon       Normal    Male      Home and lifestyle
# 3  123-19-1176      A     Yangon       Member    Male       Health and beauty
# 4  373-73-7910      A     Yangon       Normal    Male       Sports and travel
#
#    UnitPrice  Quantity    Tax5%     Total       Date   Time      Payment  \
# 0      74.69         7  26.1415  548.9715   1/5/2019  13:08          NaN
# 1      15.28         5   3.8200   80.2200   3/8/2019  10:29         Cash
# 2      46.33         7  16.2155  340.5255   3/3/2019  13:23  Credit card
# 3      58.22         8  23.2880  489.0480  1/27/2019  20:33          NaN
# 4      86.31         7  30.2085  634.3785   2/8/2019  10:37      Ewallet
#
#      cogs  grossMarginPercentage  GrossIncome  Rating
# ...

# %%
df.GrossIncome
# Out:
# 0      26.1415
# 1       3.8200
# 2      16.2155
# 3          NaN
# 4      30.2085
#         ...
# 995     2.0175
# 996    48.6900
# 997     1.5920
# 998     3.2910
# 999    30.9190
# Name: GrossIncome, Length: 1000, dtype: float64

# %%
df=df[0:200].fillna(method='ffill') #Fills NaN values in the 0:200 rows

# %%
kd1 = sns.kdeplot(df[:100].Rating, df[:100].Quantity)

# %%
kd1 = sns.kdeplot(df[:100].Rating, df[:100].Quantity,shade=True)

# %%
kd1 = sns.kdeplot(df[:100].Rating, df[:100].Quantity,shade=True,shade_lowest=False)

# %%
sns.set_style("darkgrid")
kd1 = sns.kdeplot(df[:100].Rating, df[:100].Quantity,\
                  shade =True, cmap ="copper_r",shade_lowest=False)

# %%
f, ax= plt.subplots(1,2, figsize = (12,6)) #creates 2 figures as 1x2 matrix

# %%
kd1 = sns.kdeplot(df[:100].Rating, df[:100].Quantity,\
                  shade =True, cmap ="copper_r",shade_lowest=False)

# %%
kd2 = sns.kdeplot(df[:100].Quantity, df[:100].GrossIncome,\
                  shade =True, cmap ="Reds",shade_lowest=False)

# %%
#Dashboard
f, ax = plt.subplots(1,2, figsize = (12,6))
kd1 = sns.kdeplot(df[:100].Rating, df[:100].Quantity,shade =True, cmap ="copper_r",shade_lowest=False)
kd2 = sns.kdeplot(df[:100].Quantity, df[:100].GrossIncome,shade =True, cmap ="Reds",shade_lowest=False)

# %%
f, axes = plt.subplots(1,2, figsize = (12,6))
kd1 = sns.kdeplot(df[:100].Rating, df[:100].Quantity,shade =True, cmap ="copper_r",shade_lowest=False,ax=axes[0])
kd2 = sns.kdeplot(df[:100].Quantity, df[:100].GrossIncome,shade =True, cmap ="Reds",shade_lowest=False,ax=axes[1])

# %%
a, b= plt.subplots(2,2, figsize = (12,6)) # creates 2x2 matrix

# %%
a, b= plt.subplots(2,2, figsize = (12,6))
plt1=b[0,0].hist([df[df.City == 'Yangon'].Total, df[df.City == 'Mandalay'].Total, df[df.City == 'Naypyitaw'].Total],bins =15, stacked = True)
plt2 =sns.kdeplot(df[:100].Quantity, df[:100].GrossIncome,shade =True, cmap ="inferno",shade_lowest=True,ax=b[0,1])
plt3=b[1,0].scatter(data = df, x ="Rating", y = "Total",cmap="")
plt4=sns.boxplot(data=df,x="ProductLine",y="cogs",ax=b[1,1])

# %%
plt.hist([df.Rating,df.Quantity],bins=10)
# Out:
# ([array([ 0.,  0.,  0., 18., 28., 33., 30., 29., 29., 33.]),
#   array([16., 15., 14., 15., 20., 27., 20., 25., 22., 26.])],
#  array([ 1. ,  1.9,  2.8,  3.7,  4.6,  5.5,  6.4,  7.3,  8.2,  9.1, 10. ]),
#  <a list of 2 Lists of Patches objects>)
